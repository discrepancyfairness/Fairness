# %%
prec_z_adult=[0.7643, 0.7531,0.7623, 0.7702,0.7681, 0.7814,0.7524, 0.8089]
rec_z_adult=[0.6286, 0.6136,0.6410, 0.6424,0.5902, 0.6387,0.6021, 0.6585]
acc_z_adult=[0.8519, 0.8511,0.8511, 0.8502,0.8418, 0.8404,0.8357, 0.8519]

diff_prec_z_adult=[-0.0112  0.0079  0.0133  0.0565] 
diff_rec_z_adult=[-0.015   0.0014  0.0485  0.0564] 
diff_acc_z_adult=[-0.0008 -0.0009 -0.0014  0.0162]
DP_z_adult=[0.1698 0.1618 0.157 0.1074]

prec_z_bank=[0.6302, 0.6924,0.6433, 0.6948,0.6653, 0.6915,0.6370, 0.6893]
rec_z_bank=[NA]
acc_z_bank=[0.9065, 0.9083,0.9064, 0.9080,0.9036, 0.9073,0.9027, 0.9079]

diff_prec_z_bank=[0.0622 0.0515 0.0262 0.0523] 
diff_acc_z_bank=[0.0018 0.0016 0.0037 0.0052]
DP_z_bank=[0.1715, 0.0849, 0.0495, 0.0656]

prec_z_comp=[0.6021, 0.6348,0.6181, 0.6250,0.6028, 0.6237,0.5881, 0.6250]
rec_z_comp=[0.6288, 0.6260,0.6412, 0.6100,0.6537, 0.6177,0.6606, 0.6190]
acc_z_comp=[0.6654, 0.6831,0.6622, 0.6752,0.6554, 0.6600,0.6559, 0.6601]

diff_prec_z_comp=[0.0327 0.0069 0.0209 0.0369]
diff_rec_z_comp=[-0.0028 -0.0312 -0.036  -0.0416]
diff_acc_z_comp=[0.0177 0.013  0.0046 0.0042]

DP_z_comp=[0.1482, 0.0092, 0.07, 0.0668]

# %%
import json
import numpy as np
#adult
'''
prec=[0.7643, 0.7531,0.7623, 0.7702,0.7681, 0.7814,0.7524, 0.8089]
rec=[0.6286, 0.6136,0.6410, 0.6424,0.5902, 0.6387,0.6021, 0.6585]
acc=[0.8519, 0.8511,0.8511, 0.8502,0.8418, 0.8404,0.8357, 0.8519]

#bank
prec=[0.6302, 0.6924,0.6433, 0.6948,0.6653, 0.6915,0.6370, 0.6893]
#rec=[NA]
acc=[0.9065, 0.9083,0.9064, 0.9080,0.9036, 0.9073,0.9027, 0.9079]
'''
#compas
prec=[0.6021, 0.6348,0.6181, 0.6250,0.6028, 0.6237,0.5881, 0.6250]
rec=[0.6288, 0.6260,0.6412, 0.6100,0.6537, 0.6177,0.6606, 0.6190]
acc=[0.6654, 0.6831,0.6622, 0.6752,0.6554, 0.6600,0.6559, 0.6601]

data1=np.zeros(4,dtype=float)
data2=np.zeros(4,dtype=float)
'''
for i in range(4):
    data1[i]=prec[2*i+1]
    data2[i]=prec[2*i]
'''
for i in range(4):
    data1[i]=rec[2*i+1]
    data2[i]=rec[2*i]
'''   
for i in range(4):
    data1[i]=acc[2*i+1]
    data2[i]=acc[2*i]    
'''

# Paired Student's t-test
from numpy.random import seed
from numpy.random import randn
from scipy.stats import ttest_rel

stat, p = ttest_rel(data1, data2)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
    print('Same distributions (fail to reject H0)')
else:
    print('Different distributions (reject H0)')
'''
Statistics=1.163, p=0.329
Statistics=1.304, p=0.283
Statistics=0.760, p=0.503


prec Statistics=6.257, p=0.008
acc Statistics=3.610, p=0.037


Statistics=3.618, p=0.036
Statistics=-3.232, p=0.048
Statistics=2.988, p=0.058
'''
# Out:
# Statistics=-3.232, p=0.048
# Different distributions (reject H0)
# '\nStatistics=1.163, p=0.329\nStatistics=1.304, p=0.283\nStatistics=0.760, p=0.503\n\n\nprec Statistics=6.257, p=0.008\nacc Statistics=3.610, p=0.037\n\n\nStatistics=3.618, p=0.036\nStatistics=-3.232, p=0.048\nStatistics=2.988, p=0.058\n'

# %%
prec_a_adult=[0.7313,0.7313,0.7341, 0.7315,0.7726, 0.7635,0.7825, 0.7777]
rec_a_adult=[0.4982, 0.4873,0.5097, 0.5084,0.6266, 0.6501,0.6657, 0.6856]
acc_a_adult=[0.8466, 0.8426,0.8351, 0.8374,0.8191, 0.8299,0.8035, 0.8165]

diff_prec_a_adult=[ 0.     -0.0026 -0.0091 -0.0048] 
diff_rec_a_adult=[-0.0109 -0.0013  0.0235  0.0199] 
diff_acc_a_adult=[-0.004   0.0023  0.0108  0.013 ]

DP_a_adult=[0.2251,0.2126,0.1266,0.0711]

prec_a_bank=[0.6751, 0.6876,0.6748, 0.6877,0.6504, 0.6854,0.6404, 0.6904]
rec_a_bank=[NA]
acc_a_bank=[0.9075, 0.9124,0.9039, 0.9113,0.9028, 0.9101,0.9049, 0.9107]

diff_prec_a_bank=[0.0125 0.0129 0.035  0.05  ] 
diff_acc_a_bank=[0.0049 0.0074 0.0073 0.0058]
DP_a_bank=[0.0537  0.054  0.0376 0.0335]

prec_a_comp=[NA]
rec_a_comp=[0.6248, 0.6409,0.6394, 0.6397,0.6528, 0.6572,0.6610, 0.6727]
acc_a_comp=[0.6414, 0.6571,0.6559, 0.6578,0.6458, 0.6515,0.6344, 0.6458]

diff_rec_a_comp=[0.0161 0.0003 0.0044 0.0117] 
diff_acc_a_comp=[0.0157 0.0019 0.0057 0.0114]
DP_a_comp=[0.1138  0.0742  0.0541  0.0251]

# %%
import json
import numpy as np
'''
prec=[0.7313,0.7313,0.7341, 0.7315,0.7726, 0.7635,0.7825, 0.7777]
rec=[0.4982, 0.4873,0.5097, 0.5084,0.6266, 0.6501,0.6657, 0.6856]
acc=[0.8466, 0.8426,0.8351, 0.8374,0.8191, 0.8299,0.8035, 0.8165]



prec=[0.6751, 0.6876,0.6748, 0.6877,0.6504, 0.6854,0.6404, 0.6904]
#rec=[NA]
acc=[0.9075, 0.9124,0.9039, 0.9113,0.9028, 0.9101,0.9049, 0.9107]

'''
#prec=[NA]
rec=[0.6248, 0.6409,0.6394, 0.6397,0.6528, 0.6572,0.6610, 0.6727]
acc=[0.6414, 0.6571,0.6559, 0.6578,0.6458, 0.6515,0.6344, 0.6458]




data1=np.zeros(4,dtype=float)
data2=np.zeros(4,dtype=float)
''' 
for i in range(4):
    data1[i]=prec[2*i+1]
    data2[i]=prec[2*i]
'''  
for i in range(4):
    data1[i]=rec[2*i+1]
    data2[i]=rec[2*i]
'''   
for i in range(4):
    data1[i]=acc[2*i+1]
    data2[i]=acc[2*i]    
'''

# Paired Student's t-test
from numpy.random import seed
from numpy.random import randn
from scipy.stats import ttest_rel

stat, p = ttest_rel(data1, data2)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
    print('Same distributions (fail to reject H0)')
else:
    print('Different distributions (reject H0)')
    
'''
Statistics=-2.141, p=0.122
Statistics=0.940, p=0.416
Statistics=1.408, p=0.254

prec Statistics=3.022, p=0.057
acc  Statistics=10.475, p=0.002

rec Statistics=2.287, p=0.106
acc Statistics=2.846, p=0.065
'''
# Out:
# Statistics=2.287, p=0.106
# Same distributions (fail to reject H0)
# '\nStatistics=-2.141, p=0.122\nStatistics=0.940, p=0.416\nStatistics=1.408, p=0.254\n\nprec Statistics=3.022, p=0.057\nacc  Statistics=10.475, p=0.002\n\nrec \nacc Statistics=2.846, p=0.065\n'

# %%
prec_y_adult=[0.6605, 0.8163,0.7397, 0.8481,0.7234, 0.8486,0.6424, 0.8168]
rec_y_adult=[NA]
acc_y_adult=[0.7985, 0.8361,0.8027, 0.8222,0.7925, 0.8093,0.7812, 0.8076]

diff_prec_y_adult=[0.1558 ,0.1084 ,0.1252, 0.1744] 
diff_acc_y_adult=[0.0376 ,0.0195 ,0.0168 ,0.0264]

DP_y_adult=[0.1169 ,0.0853, 0.0532,  0.018]

#there our
prec_y_bank=[0.6701, 0.6650,0.6641 ,0.6751,0.6490 , 0.6741,0.6484, 0.7323]
rec_y_bank=[NA]
acc_y_bank=[0.9085, 0.9083,0.9025, 0.9038,0.9044, 0.9075,0.8935,0.8969]

diff_prec_y_bank=[-0.0051 , 0.011,   0.0251,  0.0839] 
diff_acc_y_bank=[-0.0002,  0.0013 , 0.0031 , 0.0034]

DP_y_bank=[0.1497, 0.0686 ,0.0276, 0.0069]

prec_y_comp=[0.6583, 0.6640,0.5973, 0.6659,0.5056, 0.7277,0.5830, 0.6973]
rec_y_comp=[0.4405, 0.4627,0.3878, 0.5014,0.2631, 0.4071,0.2908, 0.4487]
acc_y_comp=[0.6805, 0.6805,0.5833, 0.6489,0.5252, 0.6262,0.5580, 0.6388]

diff_prec_y_comp=[0.0057, 0.0686, 0.2221, 0.1143] 
diff_rec_y_comp=[0.0222 ,0.1136 ,0.144 , 0.1579] 
diff_acc_y_comp=[0.  ,   0.0656, 0.101,  0.0808]

DP_y_comp=[0.2591, 0.0850, 0.0746, 0.0356]

# %%
import json
import numpy as np

prec=[0.6605, 0.8163,0.7397, 0.8481,0.7234, 0.8486,0.6424, 0.8168]
#rec=[NA]
acc=[0.7985, 0.8361,0.8027, 0.8222,0.7925, 0.8093,0.7812, 0.8076]
'''

prec=[0.6701, 0.6650,0.6641 ,0.6751,0.6490 , 0.6741,0.6484, 0.7323]
#rec=[NA]
acc=[0.9085, 0.9083,0.9025, 0.9038,0.9044, 0.9075,0.8935,0.8969]


prec=[0.6583, 0.6640,0.5973, 0.6659,0.5056, 0.7277,0.5830, 0.6973]
rec=[0.4405, 0.4627,0.3878, 0.5014,0.2631, 0.4071,0.2908, 0.4487]
acc=[0.6805, 0.6805,0.5833, 0.6489,0.5252, 0.6262,0.5580, 0.6388]
'''

data1=np.zeros(4,dtype=float)
data2=np.zeros(4,dtype=float)
'''
for i in range(4):
    data1[i]=prec[2*i+1]
    data2[i]=prec[2*i]
  
for i in range(4):
    data1[i]=rec[2*i+1]
    data2[i]=rec[2*i]
'''    
for i in range(4):
    data1[i]=acc[2*i+1]
    data2[i]=acc[2*i]    


# Paired Student's t-test
from numpy.random import seed
from numpy.random import randn
from scipy.stats import ttest_rel

stat, p = ttest_rel(data1, data2)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
    print('Same distributions (fail to reject H0)')
else:
    print('Different distributions (reject H0)')
'''
prec= Statistics=9.490, p=0.002
acc = Statistics=5.406, p=0.012

prec Statistics=1.481, p=0.235
acc  Statistics=2.263, p=0.109

Statistics=2.251, p=0.110
Statistics=3.586, p=0.037
Statistics=2.830, p=0.066
'''
# Out:
# Statistics=5.406, p=0.012
# Different distributions (reject H0)
# '\nprec= Statistics=9.490, p=0.002\nacc = \n\nprec Statistics=1.481, p=0.235\nacc  Statistics=2.263, p=0.109\n\nStatistics=2.251, p=0.110\nStatistics=3.586, p=0.037\nStatistics=2.830, p=0.066\n'

# %%
lp4_adult_prec=[ 0.7347, 0.7427,  0.7607, 0.7647] 
lp4_adult_rec=[ 0.5445, 0.5956,  0.6816, 0.7036]
lp4__adult_acc=[ 0.846, 0.8424,  0.8337, 0.8264]

lp4_prec_adult_nocv=[ 0.7271, 0.7219,  0.7102, 0.7039] 
lp4_rec_adult_nocv=[ 0.5034, 0.5066,  0.5129, 0.5167]
lp4_acc_adult_nocv=[ 0.8405, 0.8289, 0.8059, 0.7945]

prec=[0.7271, 0.7347, 0.7219,0.7427,  0.7102, 0.7607, 0.7039,0.7647] 
rec=[ 0.5034,0.5445, 0.5066,0.5956, 0.5129, 0.6816, 0.5167,0.7036]
acc=[ 0.8405,0.846, 0.8289,0.8424,  0.8059,0.8337,  0.7945,0.8264]

diff_lp4_adult_prec=[0.0076, 0.0208, 0.0505, 0.0608] 
diff_lp4_adult_rec=[0.0411, 0.089 , 0.1687 ,0.1869]
dp_lp4_adult=[ 0.2188, 0.1630,  0.0539, 0.0019]
accu=[0.0055, 0.0135, 0.0278, 0.0319]

###########3
lp4_comp_prec=[0.6604,0.6604,0.6494,0.6657,0.64602,0.6664,0.6398,0.6706]
lp4_comp_rec=[0.4265,0.4265,0.0.5124,5262,0.5568,0.5484,0.5845,0.5650]
acc=[0.6805,0.6805,0.6489,0.6628,0.6426,0.6542,0.63,0.6452]




diff_lp4_comp_prec=[0.,      0.0163,  0.02038, 0.0308 ]
diff_lp4_comp_rec=[ 0.,      0.0138, -0.0084, -0.0195]
accu=[0.,     0.0139, 0.0116, 0.0152]

dp_lp4_comp=[0.3060, 0.1212, 0.0613, 0.0028]
############3



#2,4,5 6 
weight_prec_nocv=[ 0.6621,  0.6485, 0.6413, 0.6511] 
weight_rec_nocv=[ 0.4611,  0.4552, 0.4504, 0.4430]

lp4_prec_bank=[ 0.6752,  0.6626, 0.6568, 0.6466] 
lp4_rec_bank=[ 0.4947,  0.5683, 0.6061, 0.6298]

prec=[ 0.6621,0.6752  ,0.6485,0.6626, 0.6413,0.6568 ,0.6511,0.6466] 
rec=[ 0.4611,0.4947,  0.4552,0.5683, 0.4504,0.6061, 0.4430,0.6298]
acc=[0.9104,0.9129,0.9075,0.9106,0.9062,0.908,0.9044,0.9067]


accu=[0.0025, 0.0031, 0.0018, 0.0023]
diff_lp4_bank_prec=[ 0.0131,  0.0141,  0.0155, -0.0045] 
diff_lp4_bank_rec=[0.0336, 0.1131, 0.1557, 0.1868]

dp_lp4_bank=[ 0.1968, 0.0988, 0.0512, 0.0198]




# bank compass 0.0024 0.0101  

################################################################
diff_lp4_adult_prec=[0.0076, 0.0208, 0.0505, 0.0608] 
diff_lp4_adult_rec=[0.0411, 0.089 , 0.1687 ,0.1869]
dp_lp4_adult=[ 0.2188, 0.1630,  0.0539, 0.0019]


diff_lp4_comp_prec=[0.,      0.0163,  0.02038, 0.0308 ]
diff_lp4_comp_rec=[ 0.,      0.0138, -0.0084, -0.0195]
dp_lp4_comp=[0.3060, 0.1212, 0.0613, 0.0028]


diff_lp4_bank_prec=[ 0.0131,  0.0141,  0.0155, -0.0045] 
diff_lp4_bank_rec=[0.0336, 0.1131, 0.1557, 0.1868]
dp_lp4_bank=[ 0.1968, 0.0988, 0.0512, 0.0198]

# %%
import json
import numpy as np
'''
prec=[0.7271, 0.7347, 0.7219,0.7427,  0.7102, 0.7607, 0.7039,0.7647] 
rec=[ 0.5034,0.5445, 0.5066,0.5956, 0.5129, 0.6816, 0.5167,0.7036]
acc=[ 0.8405,0.846, 0.8289,0.8424,  0.8059,0.8337,  0.7945,0.8264]


prec=[ 0.6621,0.6752  ,0.6485,0.6626, 0.6413,0.6568 ,0.6511,0.6466] 
rec=[ 0.4611,0.4947,  0.4552,0.5683, 0.4504,0.6061, 0.4430,0.6298]
acc=[0.9104,0.9129,0.9075,0.9106,0.9062,0.908,0.9044,0.9067]
'''
prec=[0.6604,0.6604,0.6494,0.6657,0.64602,0.6664,0.6398,0.6706]
rec=[0.4265,0.4265,0.5124,5262,0.5568,0.5484,0.5845,0.5650]
acc=[0.6805,0.6805,0.6489,0.6628,0.6426,0.6542,0.63,0.6452]


data1=np.zeros(4,dtype=float)
data2=np.zeros(4,dtype=float)
'''   
for i in range(4):
    data1[i]=prec[2*i+1]
    data2[i]=prec[2*i]
    
    
for i in range(4):
    data1[i]=rec[2*i+1]
    data2[i]=rec[2*i]
'''   
for i in range(4):
    data1[i]=acc[2*i+1]
    data2[i]=acc[2*i]    


# Paired Student's t-test
from numpy.random import seed
from numpy.random import randn
from scipy.stats import ttest_rel

stat, p = ttest_rel(data1, data2)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
    print('Same distributions (fail to reject H0)')
else:
    print('Different distributions (reject H0)')
'''
Statistics=2.807, p=0.067
Statistics=3.552, p=0.038
Statistics=3.197, p=0.049

Statistics=2.028, p=0.136
Statistics=3.684, p=0.035
Statistics=9.019, p=0.003


Statistics=2.637, p=0.078
Statistics=1.000, p=0.391
Statistics=2.930, p=0.061
'''
# Out:
# Statistics=2.930, p=0.061
# Same distributions (fail to reject H0)
# '\nStatistics=2.807, p=0.067\nStatistics=3.552, p=0.038\nStatistics=3.197, p=0.049\n\nStatistics=2.028, p=0.136\nStatistics=3.684, p=0.035\nStatistics=9.019, p=0.003\n\n\nStatistics=2.637, p=0.078\nStatistics=1.000, p=0.391\n'

# %%
#padala acc

weighted_prec_adult=[0.721641003906538, 0.7346700670745191, 0.7566161789636617, 0.7968153571165327]
weighted_prec_adult_padala=[0.7281943355200116, 0.7376327854352472, 0.735319517947962, 0.7952423859364635] 

prec=[0.7281943355200116,0.721641003906538,0.7376327854352472, 0.7346700670745191, 0.735319517947962, 0.7566161789636617,0.7952423859364635, 0.7968153571165327]
acc=[0.8379,0.8385,0.8301,0.8315,0.8127,0.8160,0.8031,0.8029]

acc=[ 0.0006  0.0014  0.0033 -0.0002]
diff_padala_adult_prec=[-0.00655333 ,-0.00296272  ,0.02129666 , 0.00157297]
dp_padala_adult=[ 0.1435,0.1028,0.0793,0.0658]


#correct it

weighted_rec_comp_padala=[0.6570,0.6510, 0.6551,0.6467, 0.6171,0.62, 0.6671,0.6792]
acc=[0.6628,0.6590, 0.6609,0.6546 0.6590,0.6515,  0.6256,0.6395]

acc=[-0.0038 -0.0063 -0.0075  0.0139]
diff_padala_comp_rec=[-0.006  -0.0084  0.0029  0.0121] 
dp_padala_comp=[0.18653,0.1099,0.0617,0.0154]




################################################################################

prec=[ 0.6621,0.6581  ,0.6575,0.6588, 0.6412,0.6712 ,0.63,0.68] 

acc=[0.9085, 0.9083,0.9025, 0.9038,0.8844, 0.9075,0.8735,0.8969]

##########################################################################################


acc=[0.9085, 0.9083,0.9025, 0.9038,0.8844, 0.9075,0.8735,0.8969]

acc=acc=[-0.0002  0.0013  0.0231  0.0234]
diff_padala_bank_prec=[-0.004 , 0.012,   0.03,  0.05] 

dp_padala_bank=[0.2291, 0.0650, 0.04, 0.02]

# %%
import json
import numpy as np

prec=[0.7281943355200116,0.721641003906538,0.7376327854352472, 0.7346700670745191, 0.735319517947962, 0.7566161789636617,0.7952423859364635, 0.7968153571165327]
acc=[0.8379,0.8385,0.8301,0.8315,0.8127,0.8160,0.8031,0.8029]
'''
prec=[ 0.6621,0.6581  ,0.6575,0.6588, 0.6412,0.6712 ,0.63,0.68] 
acc=[0.9085, 0.9083,0.9025, 0.9038,0.8844, 0.9075,0.8735,0.8969]



rec=[0.6570,0.6510, 0.6551,0.6467, 0.6171,0.62, 0.6671,0.6792]
acc=[0.6628,0.6590, 0.6609,0.6546, 0.6590,0.6515,  0.6256,0.6395]
'''


data1=np.zeros(4,dtype=float)
data2=np.zeros(4,dtype=float)
'''
for i in range(4):
    data1[i]=prec[2*i+1]
    data2[i]=prec[2*i]
  
for i in range(4):
    data1[i]=rec[2*i+1]
    data2[i]=rec[2*i]
'''    
for i in range(4):
    data1[i]=acc[2*i+1]
    data2[i]=acc[2*i]    


# Paired Student's t-test
from numpy.random import seed
from numpy.random import randn
from scipy.stats import ttest_rel

stat, p = ttest_rel(data1, data2)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
    print('Same distributions (fail to reject H0)')
else:
    print('Different distributions (reject H0)')
'''
prec Statistics=0.537, p=0.628
acc Statistics=1.700, p=0.188

prec Statistics=1.526, p=0.224
acc Statistics=1.814, p=0.167

rec Statistics=0.032, p=0.976
acc Statistics=-0.185, p=0.865
'''
# Out:
# Statistics=1.700, p=0.188
# Same distributions (fail to reject H0)
# '\nprec Statistics=0.537, p=0.628\n\nprec Statistics=1.526, p=0.224\nStatistics=1.814, p=0.167\n\nrec Statistics=0.032, p=0.976\nStatistics=-0.185, p=0.865\n'

# %%
#madras
madras_prec_adult=[0.7339,0.7334,0.7300, 0.7333,0.7699 ,0.7589,0.7915, 0.7891]
madras_rec_adult=[0.5914, 0.6140,0.5961, 0.6111,0.6752, 0.7329,0.7478, 0.7692]
accu=[0.8512,0.8508, 0.8500,0.8502,0.8457,0.8400,0.8358,0.8323]
  
dp_adult_madras=[0.1706,0.155,0.0927,0.0332]
diff_madras_adult_prec=[-0.0005 , 0.0033, -0.011 , -0.0024] 
diff_madras_adult_rec=[0.0226, 0.015,  0.0577, 0.0214] 

accu=[-0.0004,  0.0002, -0.0057 ,-0.0035]


# p r a
avg_bank_r_up=[-0.0026 0.02917 -0.0023]




madras_prec_bank=[0.7821, 0.79,0.8043, 0.7692,0.7701,0.7674,0.8153, 0.773]
madras_rec_bank=[0.4612, 0.4825,0.4417, 0.4646,0.4723, 0.4893,0.4476, 0.4731]
accu=[0.9095,0.9137,0.9096,0.9132,0.9096,0.9129,0.9075,0.9116 ]





dp_bank_madras=[ 0.1004,0.0887,0.0751,0.0403]
diff_madras_bank_prec=[ 0.0079, -0.0351, -0.0027, -0.0423]
diff_madras_bank_rec=[0.0213, 0.0229, 0.017,  0.0255] 
accu=[0.0042, 0.0036, 0.0033, 0.0041]
# p r a
avg_bank_r_up=[-0.0180,0.0216,0.0037]

         

    
    
madras_prec_comp=[0.6791, 0.6828,0.6851, 0.6851,0.6723, 0.6801,0.7084, 0.6948] 
madras_rec_comp=[0.4957,0.4957,0.4705, 0.4915,0.5569, 0.5714 ,0.5294,  0.5462]
accu=[0.6660,0.6685  ,0.6641, 0.6654 ,0.6641, 0.6679 ,0.6616, 0.6603]

dp_comp_madras=[ 0.1438,0.1246,0.0953,0.0403]
diff_madras_comp_prec=[ 0.0037 , 0. ,     0.0078, -0.0136]
diff_padala_comp_rec=[0.   ,  0.021 , 0.0145 ,0.0168]  

accu=[ 0.0025 , 0.0013 , 0.0038, -0.0013]
-0.00052,0.013075,0.001575
       






dp_adult_madras=[0.1706,0.155,0.0927,0.0332]
diff_madras_adult_prec=[0.0426 ,0.0401, 0.0193, 0.0134]
diff_madras_adult_rec=[0.2056 ,0.2115, 0.1175 ,0.0321]



dp_bank_madras=[ 0.1004,0.0887,0.0751,0.0403]
diff_madras_bank_prec=[ 0.0029, -0.0369, -0.0027 ,-0.0785]
diff_madras_bank_rec=[    0.326 , 0.308 , 0.2774 ,0.1524]


dp_comp_madras=[ 0.1438,0.1246,0.0953,0.0403]
diff_madras_comp_prec=[0.0144 , 0.0128,  0.0113, -0.0071]
diff_madras_comp_rec=[0.0967  ,0.1093  ,0.0523 ,-0.028]

# %%
import json
import numpy as np
'''
prec=[0.7339,0.7334,0.7300, 0.7333,0.7699 ,0.7589,0.7915, 0.7891]
rec=[0.5914, 0.6140,0.5961, 0.6111,0.6752, 0.7329,0.7478, 0.7692]
acc=[0.8512,0.8508, 0.8500,0.8502,0.8457,0.8400,0.8358,0.8323]

'''
prec=[0.7821, 0.79,0.8043, 0.7692,0.7701,0.7674,0.8153, 0.773]
rec=[0.4612, 0.4825,0.4417, 0.4646,0.4723, 0.4893,0.4476, 0.4731]
acc=[0.9095,0.9137,0.9096,0.9132,0.9096,0.9129,0.9075,0.9116]
          
        
'''    
prec=[0.6791, 0.6828,0.6851, 0.6851,0.6723, 0.6801,0.7084, 0.6948] 
rec=[0.4957,0.4957,0.4705, 0.4915,0.5569, 0.5714 ,0.5294,  0.5462]
acc=[0.6660,0.6685  ,0.6641, 0.6654 ,0.6641, 0.6679 ,0.6616, 0.6603]

'''




data1=np.zeros(4,dtype=float)
data2=np.zeros(4,dtype=float)
'''
for i in range(4):
    data1[i]=prec[2*i+1]
    data2[i]=prec[2*i]
   
for i in range(4):
    data1[i]=rec[2*i+1]
    data2[i]=rec[2*i]
'''
for i in range(4):
    data1[i]=acc[2*i+1]
    data2[i]=acc[2*i]    


# Paired Student's t-test
from numpy.random import seed
from numpy.random import randn
from scipy.stats import ttest_rel

stat, p = ttest_rel(data1, data2)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
    print('Same distributions (fail to reject H0)')
else:
    print('Different distributions (reject H0)')
'''
Statistics=-0.876, p=0.446
Statistics=3.022, p=0.057
Statistics=-1.703, p=0.187

Statistics=-1.479, p=0.236
Statistics=12.160, p=0.001
Statistics=17.913, p=0.000

Statistics=-0.113, p=0.917
Statistics=2.866, p=0.064
Statistics=1.451, p=0.243
'''
# Out:
# Statistics=17.913, p=0.000
# Different distributions (reject H0)
# '\nStatistics=-0.876, p=0.446\nStatistics=3.022, p=0.057\nStatistics=-1.703, p=0.187\n\nStatistics=-1.479, p=0.236\nStatistics=12.160, p=0.001\nStatistics=17.913, p=0.000\n\nStatistics=-0.113, p=0.917\nStatistics=2.866, p=0.064\nStatistics=1.451, p=0.243\n'

# %%
import numpy as np
diff_prec=np.zeros(4,dtype=float)
diff_rec=np.zeros(4,dtype=float)
diff_acc=np.zeros(4,dtype=float)
j=0
sump=0
sumr=0
suma=0
sump1=0
sumr1=0
suma1=0


prec=[ 0.6621,0.6581  ,0.6575,0.6588, 0.6412,0.6712 ,0.63,0.68] 
rec=[0.9085, 0.9083,0.9025, 0.9038,0.8844, 0.9075,0.8735,0.8969]
acc=[0.9085, 0.9083,0.9025, 0.9038,0.8844, 0.9075,0.8735,0.8969]

for i in range(0,8,2):
    sump= sump+prec[i+1]
    sumr=sumr+rec[i+1]
    suma=suma+acc[i+1]
    
    sump1= sump1+prec[i]
    sumr1=sumr1+rec[i]
    suma1=suma1+acc[i]

#print((sump/4)-(sump1/4))
#print((sumr/4)-(sumr1/4))
#print((suma/4)-(suma1/4))

print((suma1/4)) 
print((suma/4)) 
print((sump1/4))
print((sump/4))
print((sumr1/4))
print((sumr/4))
# Out:
# 0.8922249999999999
# 0.904125
# 0.6476999999999999
# 0.667025
# 0.8922249999999999
# 0.904125

# %%
import numpy as np
diff_prec=np.zeros(4,dtype=float)
diff_rec=np.zeros(4,dtype=float)
diff_acc=np.zeros(4,dtype=float)
j=0


prec=[0.7339,0.7334,0.7300, 0.7333,0.7699 ,0.7589,0.7915, 0.7891]
rec=[0.5914, 0.6140,0.5961, 0.6111,0.6752, 0.7329,0.7478, 0.7692]
acc=[0.8512,0.8508, 0.8500,0.8502,0.8457,0.8400,0.8358,0.8323]


for i in range(0,8,2):
    diff_prec[j]= prec[i+1]-prec[i]
    diff_rec[j]=rec[i+1]-rec[i]
    diff_acc[j]=acc[i+1]-acc[i]
    j=j+1
    
print(diff_prec,diff_rec,diff_acc)
# Out:
# [-0.0005  0.0033 -0.011  -0.0024] [0.0226 0.015  0.0577 0.0214] [-0.0004  0.0002 -0.0057 -0.0035]

# %%
import numpy as np
diff_prec=np.zeros(4,dtype=float)
diff_rec=np.zeros(4,dtype=float)
diff_acc=np.zeros(4,dtype=float)
j=0
sump=0
sumr=0
suma=0
sump1=0
sumr1=0
suma1=0


for i in range(0,8,2):
    sump= sump+prec[i+1]
    sumr=sumr+rec[i+1]
    suma=suma+acc[i+1]
    
    sump1= sump1+prec[i]
    sumr1=sumr1+rec[i]
    suma1=suma1+acc[i]

#print((sump/4)-(sump1/4))
#print((sumr/4)-(sumr1/4))
#print((suma/4)-(suma1/4))
   
print((sump1/4))
print((sumr1/4))
print((suma1/4)) 

   
print((sump/4))
print((sumr/4))
print((suma/4))
# Out:
# -0.0026499999999999996
# 0.029175
# -0.00235

# %%
# importing libraries
import matplotlib.pyplot as plt
import numpy as np
  
# creating two array for plotting
x = np.arange(-20, 20, 1)
y = [-30, -20, -10, -3, 1, 11, 10, 5, -20, 20, 15,
     30, 20, 2, 4, 3, -7, -8, -13, -16, 16, -15, 32,
     -12, -19, 25, -25, 30, -6, -18, -11, -14, -21,
     27, -21, -14, -4, -1, 0, 17]
  
# creating scatter plot with both negative 
# and positive axes
plt.scatter(x, y)
  
# visualizing the plot using plt.show() function
plt.show()

# %%
from matplotlib import pyplot as plt 
import numpy as np
#generate a list of markers and another of colors 
markers = ["." , "," , "o" , "v" , "^" , "<", ">"]
colors = ['r','g','b','c','m', 'y', 'k']

#make a sample dataset
x = np.arange(0,10)  #test x values.. every feature gets the same x values but you can generalize this
y = [s*x for s in np.arange(7)] #generate 7 arrays of y values 


for i in range(7): #for each of the 7 features 
    mi = markers[i] #marker for ith feature 
    xi = x #x array for ith feature .. here is where you would generalize      different x for every feature
    yi = y[i] #y array for ith feature 
    ci = colors[i] #color for ith feature 
    plt.scatter(xi,yi,s=50,marker=mi, color=ci) 
plt.show()

# %%
diff_prec_z_comp=[0.0327 ,0.0069, 0.0209, 0.0369]
diff_rec_z_comp=[-0.0028, -0.0312, -0.036,  -0.0416]
DP_z_comp=[0.1482, 0.0092, 0.07, 0.0668]

diff_rec_a_comp=[0.0161, 0.0003, 0.0044 ,0.0117] 
DP_a_comp=[0.1138 , 0.0742,  0.0541,  0.0251]

diff_prec_y_comp=[0.0057, 0.0686, 0.2221, 0.1143] 
diff_rec_y_comp=[0.0222 ,0.1136 ,0.144 , 0.1579] 
DP_y_comp=[0.2591, 0.0850, 0.0746, 0.0356]

diff_lp4_comp_prec=[0.,      0.0163,  0.02038, 0.0308 ]
diff_lp4_comp_rec=[ 0.,      0.0138, -0.0084, -0.0195]
dp_lp4_comp=[0.3060, 0.1212, 0.0613, 0.0028]


from matplotlib import pyplot as plt 

#generate a list of markers and another of colors 
markers = ["+",1,4,5,6,7,'1','2']
colors = ['r','g','b','c','m','y']

mi = markers[0]
ci = colors[2]
plt.scatter(DP_z_comp,diff_prec_z_comp,marker=mi, color=ci) 
mi = markers[1]
ci = colors[2]
plt.scatter(DP_z_comp,diff_rec_z_comp,marker=mi, color=ci) 


mi = markers[3]
ci = colors[2]
plt.scatter(DP_a_comp,diff_rec_a_comp,marker=mi, color=ci)



mi = markers[4]
ci = colors[2]
plt.scatter(DP_y_comp,diff_prec_y_comp,marker=mi, color=ci)
mi = markers[5]
ci = colors[2]
plt.scatter(DP_y_comp,diff_rec_y_comp,marker=mi, color=ci)



mi = markers[6]
ci = colors[2]
plt.scatter(dp_lp4_comp,diff_lp4_comp_prec,marker=mi, color=ci)
mi = markers[7]
ci = colors[2]
plt.scatter(dp_lp4_comp,diff_lp4_comp_rec,marker=mi, color=ci)

# %%
fig = plt.figure()
ax = plt.subplot(111)
ax.scatter(dp_lp4_comp,diff_lp4_comp_prec,marker=mi, color=ci,label='White(R)') 



   
plt.title('')
ax.set_xlabel('Demographic Parity')
ax.set_ylabel('Weighted average Precision/ Recall') 

ax.legend(loc='lower center', bbox_to_anchor=(0.5, -0.30), shadow=True, ncol=10)
plt.show()

# %%
legend1 = ax.legend(*scatter.legend_elements(),
                    loc="lower left", title="Classes")
ax.add_artist(legend1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-80-83cacc387303> in <module>
# ----> 1 legend1 = ax.legend(*scatter.legend_elements(),
#       2                     loc="lower left", title="Classes")
#       3 ax.add_artist(legend1)
#
# NameError: name 'scatter' is not defined

# %%
fig, ax = plt.subplots()

scatter1 = ax.scatter(dp_lp4_comp,diff_lp4_comp_prec,marker=mi, color=ci)
legend1 = ax.legend(*scatter1.legend_elements(),
                    loc="lower left", title="Classes")
ax.add_artist(legend1)
plt.show()

# %%
diff_prec_z_adult=[-0.0112,  0.0079,  0.0133 , 0.0565] 
diff_rec_z_adult=[-0.015 ,  0.0014,  0.0485,  0.0564] 
DP_z_adult=[0.1698, 0.1618, 0.157, 0.1074]

diff_prec_a_adult=[ 0.    , -0.0026, -0.0091, -0.0048] 
diff_rec_a_adult=[-0.0109, -0.0013,  0.0235 , 0.0199] 
DP_a_adult=[0.2251,0.2126,0.1266,0.0711]

diff_prec_y_adult=[0.1558 ,0.1084 ,0.1252, 0.1744]
DP_y_adult=[0.1169 ,0.0853, 0.0532,  0.001]

diff_lp4_adult_prec=[0.0076, 0.0208, 0.0505, 0.0608] 
diff_lp4_adult_rec=[0.0411, 0.089 , 0.1687 ,0.1869]
dp_lp4_adult=[ 0.2188, 0.1630,  0.0539, 0.0019]


diff_padala_adult_prec=[-0.00655333 ,-0.00296272  ,0.02129666 , 0.00157297]
dp_padala_adult=[ 0.1435,0.1028,0.0793,0.0658]




dp_adult_madras=[0.1706,0.155,0.0927,0.0332]
diff_madras_adult_prec=[-0.0005 , 0.0033, -0.011 , -0.0024] 
diff_madras_adult_rec=[0.0226, 0.015,  0.0577, 0.0214] 


#########################################################################################3

from matplotlib import pyplot as plt
fig = plt.figure()
ax = plt.subplot(111)
#generate a list of markers and another of colors 
markers = [3,1,4,5,6,7,'2','1','3','4','P','X']
colors = ['r','g','b','c','m','y']

mi = markers[0]
ci = colors[0]
plt.scatter(DP_z_adult,diff_prec_z_adult,s=90,marker=mi, color=ci,label='') 


mi = markers[2]
ci = colors[0]
plt.scatter(DP_z_adult,diff_prec_a_adult,s=90,marker=mi, color=ci,label='')


mi = markers[4]
ci = colors[0]
plt.scatter(DP_z_adult,diff_prec_y_adult,s=90,marker=mi, color=ci,label='')




mi = markers[6]
ci = colors[0]
plt.scatter(dp_lp4_adult,diff_lp4_adult_prec,s=90,marker=mi, color=ci,label='') 



mi = markers[8]
ci = colors[0]
plt.scatter(dp_padala_adult,diff_padala_adult_prec,s=90,marker=mi, color=ci,label='') 

mi = markers[10]
ci = colors[0]
plt.scatter(dp_adult_madras,diff_madras_adult_prec,s=90,marker=mi, color=ci,label='') 

'''
#make a sample dataset
x = np.arange(0,10)  

y = [s*x for s in np.arange(7)] 


for i in range(7): #for each of the 7 features 
    mi = markers[i] #marker for ith feature 
    xi = x #x array for ith feature .. here is where you would generalize      different x for every feature
    yi = y[i] #y array for ith feature 
    ci = colors[i] #color for ith feature 
    plt.scatter(xi,yi,marker=mi, color=ci) 
plt.show() 
'''
diff_prec_z_bank=[0.0622, 0.0515, 0.0262, 0.0523] 
DP_z_bank=[0.1715, 0.0849, 0.0495, 0.0656]

diff_prec_a_bank=[0.0125, 0.0129, 0.035,  0.05  ] 
DP_a_bank=[0.0537,  0.054,  0.0376, 0.0335]

diff_prec_y_bank=[-0.0051 , 0.011,   0.0251,  0.0839] 
DP_y_bank=[0.1497, 0.0686 ,0.0276, 0.0069]


diff_padala_bank_prec=[-0.004 , 0.012,   0.03,  0.05] 
dp_padala_bank=[0.2291, 0.0650, 0.04, 0.02]


diff_lp4_bank_prec=[ 0.0131,  0.0141,  0.0155, -0.0045] 
diff_lp4_bank_rec=[0.0336, 0.1131, 0.1557, 0.1868]
dp_lp4_bank=[ 0.1968, 0.0988, 0.0512, 0.0198]





dp_bank_madras=[ 0.1004,0.0887,0.0751,0.0403]
diff_madras_bank_prec=[ 0.0079, -0.0351, -0.0027, -0.0423]
diff_madras_bank_rec=[0.0213, 0.0229, 0.017,  0.0255] 
 
###########################################################################################33
from matplotlib import pyplot as plt 

#generate a list of markers and another of colors 


mi = markers[0]
ci = colors[1]
plt.scatter(DP_z_bank,diff_prec_z_bank,s=90,marker=mi, color=ci) 


mi = markers[2]
ci = colors[1]
plt.scatter(DP_a_bank,diff_prec_a_bank,s=90,marker=mi, color=ci)


mi = markers[4]
ci = colors[1]
plt.scatter(DP_y_bank,diff_prec_y_bank,s=90,marker=mi, color=ci)



mi = markers[6]
ci = colors[1]
plt.scatter(dp_lp4_bank,diff_lp4_bank_prec,s=90,marker=mi, color=ci)

 
mi = markers[8]
ci = colors[1]
plt.scatter(dp_padala_bank,diff_padala_bank_prec,s=90,marker=mi, color=ci)

mi = markers[10]
ci = colors[1]
plt.scatter(dp_bank_madras,diff_madras_bank_prec,s=90,marker=mi, color=ci)




diff_prec_z_comp=[0.0327 ,0.0069, 0.0209, 0.0369]
diff_rec_z_comp=[-0.0028, -0.0312, -0.036,  -0.0416]
DP_z_comp=[0.1482, 0.0092, 0.07, 0.0668]

diff_rec_a_comp=[0.0161, 0.0003, 0.0044 ,0.0117] 
DP_a_comp=[0.1138 , 0.0742,  0.0541,  0.0251]

diff_prec_y_comp=[0.0057, 0.0686, 0.2221, 0.1143] 
diff_rec_y_comp=[0.0222 ,0.1136 ,0.144 , 0.1579] 
DP_y_comp=[0.2591, 0.0850, 0.0746, 0.0356]

diff_lp4_comp_prec=[0.,      0.0163,  0.02038, 0.0308 ]
diff_lp4_comp_rec=[ 0.,      0.0138, -0.0084, -0.0195]
dp_lp4_comp=[0.3060, 0.1212, 0.0613, 0.0028]



diff_padala_comp_rec=[-0.006,  -0.0084,  0.0029,  0.0121] 
dp_padala_comp=[0.18653,0.1099,0.0617,0.0154]


dp_comp_madras=[ 0.1438,0.1246,0.0953,0.0403]
diff_madras_comp_prec=[ 0.0037 , 0. ,     0.0078, -0.0136]
diff_padala_comp_rec=[0.   ,  0.021 , 0.0145 ,0.0168]  
######################################################################################################3
from matplotlib import pyplot as plt 

#generate a list of markers and another of colors 


mi = markers[0]
ci = colors[2]
plt.scatter(DP_z_comp,diff_prec_z_comp,s=90,marker=mi, color=ci) 







mi = markers[4]
ci = colors[2]
plt.scatter(DP_y_comp,diff_prec_y_comp,s=90,marker=mi, color=ci)




mi = markers[6]
ci = colors[2]
plt.scatter(dp_lp4_comp,diff_lp4_comp_prec,s=90,marker=mi, color=ci)

mi = markers[10]
ci = colors[2]
plt.scatter(dp_comp_madras,diff_madras_comp_prec,s=90,marker=mi, color=ci)

plt.axhline(0, c='black', ls='--')

plt.title('')
ax.set_xlabel('Demographic Disparity')
ax.set_ylabel('$\delta-$Weighted Precision') 

#ax.legend(loc='lower center', bbox_to_anchor=(0.5, -0.30), shadow=True, ncol=10)
plt.show()

# %%
diff_prec_z_adult=[-0.0112,  0.0079,  0.0133 , 0.0565] 
diff_rec_z_adult=[-0.015 ,  0.0014,  0.0485,  0.0564] 
DP_z_adult=[0.1698, 0.1618, 0.157, 0.1074]

diff_prec_a_adult=[ 0.    , -0.0026, -0.0091, -0.0048] 
diff_rec_a_adult=[-0.0109, -0.0013,  0.0235 , 0.0199] 
DP_a_adult=[0.2251,0.2126,0.1266,0.0711]

diff_prec_y_adult=[0.1558 ,0.1084 ,0.1252, 0.1744]
DP_y_adult=[0.1169 ,0.0853, 0.0532,  0.001]

diff_lp4_adult_prec=[0.0076, 0.0208, 0.0505, 0.0608] 
diff_lp4_adult_rec=[0.0411, 0.089 , 0.1687 ,0.1869]
dp_lp4_adult=[ 0.2188, 0.1630,  0.0539, 0.0019]


dp_adult_madras=[0.1706,0.155,0.0927,0.0332]
diff_madras_adult_prec=[-0.0005 , 0.0033, -0.011 , -0.0024] 
diff_madras_adult_rec=[0.0226, 0.015,  0.0577, 0.0214] 
#########################################################################################3

from matplotlib import pyplot as plt1
fig = plt.figure()
ax = plt.subplot(111)
#generate a list of markers and another of colors 
markers = [3,1,4,5,6,7,'2','1','3','4','P','X']
colors = ['r','g','b','c','m','y']


mi = markers[1]
ci = colors[0]
plt.scatter(DP_z_adult,diff_rec_z_adult,s=90,marker=mi, color=ci,label='')


mi = markers[3]
ci = colors[0]
plt.scatter(DP_z_adult,diff_rec_a_adult,s=90,marker=mi, color=ci,label='')







mi = markers[7]
ci = colors[0]
plt.scatter(dp_lp4_adult,diff_lp4_adult_rec,s=90,marker=mi, color=ci,label='') 

mi = markers[11]
ci = colors[0]
plt.scatter(dp_adult_madras,diff_madras_adult_rec,s=90,marker=mi, color=ci,label='') 

'''
#make a sample dataset
x = np.arange(0,10)  

y = [s*x for s in np.arange(7)] 


for i in range(7): #for each of the 7 features 
    mi = markers[i] #marker for ith feature 
    xi = x #x array for ith feature .. here is where you would generalize      different x for every feature
    yi = y[i] #y array for ith feature 
    ci = colors[i] #color for ith feature 
    plt.scatter(xi,yi,marker=mi, color=ci) 
plt.show() 
'''
diff_prec_z_bank=[0.0622, 0.0515, 0.0262, 0.0523] 
DP_z_bank=[0.1715, 0.0849, 0.0495, 0.0656]

diff_prec_a_bank=[0.0125, 0.0129, 0.035,  0.05  ] 
DP_a_bank=[0.0537,  0.054,  0.0376, 0.0335]

diff_prec_y_bank=[-0.0051 , 0.011,   0.0251,  0.0839] 
DP_y_bank=[0.1497, 0.0686 ,0.0276, 0.0069]





diff_lp4_bank_prec=[ 0.0131,  0.0141,  0.0155, -0.0045] 
diff_lp4_bank_rec=[0.0336, 0.1131, 0.1557, 0.1868]
dp_lp4_bank=[ 0.1968, 0.0988, 0.0512, 0.0198]





dp_bank_madras=[ 0.1004,0.0887,0.0751,0.0403]
diff_madras_bank_prec=[ 0.0079, -0.0351, -0.0027, -0.0423]
diff_madras_bank_rec=[0.0213, 0.0229, 0.017,  0.0255] 


###########################################################################################33
from matplotlib import pyplot as plt 

#generate a list of markers and another of colors 







mi = markers[7]
ci = colors[1]
plt.scatter(dp_lp4_bank,diff_lp4_bank_rec,s=90,marker=mi, color=ci)

mi = markers[11]
ci = colors[1]
plt.scatter(dp_bank_madras,diff_madras_bank_rec,s=90,marker=mi, color=ci)



diff_prec_z_comp=[0.0327 ,0.0069, 0.0209, 0.0369]
diff_rec_z_comp=[-0.0028, -0.0312, -0.036,  -0.0416]
DP_z_comp=[0.1482, 0.0092, 0.07, 0.0668]

diff_rec_a_comp=[0.0161, 0.0003, 0.0044 ,0.0117] 
DP_a_comp=[0.1138 , 0.0742,  0.0541,  0.0251]

diff_prec_y_comp=[0.0057, 0.0686, 0.2221, 0.1143] 
diff_rec_y_comp=[0.0222 ,0.1136 ,0.144 , 0.1579] 
DP_y_comp=[0.2591, 0.0850, 0.0746, 0.0356]

diff_lp4_comp_prec=[0.,      0.0163,  0.02038, 0.0308 ]
diff_lp4_comp_rec=[ 0.,      0.0138, -0.0084, -0.0195]
dp_lp4_comp=[0.3060, 0.1212, 0.0613, 0.0028]


diff_padala_comp_rec=[-0.006 , -0.0084,  0.0029,  0.0121] 
dp_padala_comp=[0.18653,0.1099,0.0617,0.0154]



dp_comp_madras=[ 0.1438,0.1246,0.0953,0.0403]
diff_madras_comp_prec=[ 0.0037 , 0. ,     0.0078, -0.0136]
diff_padala_comp_rec=[0.   ,  0.021 , 0.0145 ,0.0168]  
######################################################################################################3
from matplotlib import pyplot as plt 

#generate a list of markers and another of colors 



mi = markers[1]
ci = colors[2]
plt.scatter(DP_z_comp,diff_rec_z_comp,s=90,marker=mi, color=ci) 


mi = markers[3]
ci = colors[2]
plt.scatter(DP_a_comp,diff_rec_a_comp,s=90,marker=mi, color=ci)




mi = markers[5]
ci = colors[2]
plt.scatter(DP_y_comp,diff_rec_y_comp,s=90,marker=mi, color=ci)




mi = markers[7]
ci = colors[2]
plt.scatter(dp_lp4_comp,diff_lp4_comp_rec,s=90,marker=mi, color=ci)



mi = markers[9]
ci = colors[2]
plt.scatter(dp_padala_comp,diff_padala_comp_rec,s=90,marker=mi, color=ci)

mi = markers[11]
ci = colors[2]
plt.scatter(dp_comp_madras,diff_madras_comp_rec,s=90,marker=mi, color=ci)

plt.axhline(0, c='black', ls='--')
plt.title('')
ax.set_xlabel('Demographic Disparity')
ax.set_ylabel('$\delta-$Weighted Recall') 

#ax.legend(loc='lower center', bbox_to_anchor=(0.5, -0.30), shadow=True, ncol=10)
plt.show()

# %%
diff_prec_z_adult=[-0.0112,  0.0079,  0.0133 , 0.0565] 
diff_rec_z_adult=[-0.015 ,  0.0014,  0.0485,  0.0564] 
DP_z_adult=[0.1698, 0.1618, 0.157, 0.1074]

diff_prec_a_adult=[ 0.    , -0.0026, -0.0091, -0.0048] 
diff_rec_a_adult=[-0.0109, -0.0013,  0.0235 , 0.0199] 
DP_a_adult=[0.2251,0.2126,0.1266,0.0711]

diff_prec_y_adult=[0.1558 ,0.1084 ,0.1252, 0.1744]
DP_y_adult=[0.1169 ,0.0853, 0.0532,  0.001]

diff_lp4_adult_prec=[0.0076, 0.0208, 0.0505, 0.0608] 
diff_lp4_adult_rec=[0.0411, 0.089 , 0.1687 ,0.1869]
dp_lp4_adult=[ 0.2188, 0.1630,  0.0539, 0.0019]


#########################################################################################3

from matplotlib import pyplot as plt
fig = plt.figure()
ax = plt.subplot(111)
#generate a list of markers and another of colors 
markers = [3,1,4,5,6,7,'2','1','3','4','P','X']
colors = ['r','g','b','c','m','black']

mi = markers[0]
ci = colors[5]
plt.scatter(DP_z_adult,diff_prec_z_adult,s=90,marker=mi, color=ci,label='(1)') 


mi = markers[2]
ci = colors[5]
plt.scatter(DP_z_adult,diff_prec_a_adult,s=90,marker=mi, color=ci,label='(2)')


mi = markers[4]
ci = colors[5]
plt.scatter(DP_z_adult,diff_prec_y_adult,s=90,marker=mi, color=ci,label='(3)')




mi = markers[6]
ci = colors[5]
plt.scatter(dp_lp4_adult,diff_lp4_adult_prec,s=90,marker=mi, color=ci,label='(4)') 


mi = markers[8]
ci = colors[5]
plt.scatter(dp_lp4_adult,diff_lp4_adult_prec,s=90,marker=mi, color=ci,label='(5)') 

mi = markers[10]
ci = colors[5]
plt.scatter(dp_lp4_adult,diff_lp4_adult_prec,s=90,marker=mi, color=ci,label='(6)') 

'''
#make a sample dataset
x = np.arange(0,10)  

y = [s*x for s in np.arange(7)] 


for i in range(7): #for each of the 7 features 
    mi = markers[i] #marker for ith feature 
    xi = x #x array for ith feature .. here is where you would generalize      different x for every feature
    yi = y[i] #y array for ith feature 
    ci = colors[i] #color for ith feature 
    plt.scatter(xi,yi,marker=mi, color=ci) 
plt.show() 
'''
diff_prec_z_bank=[0.0622, 0.0515, 0.0262, 0.0523] 
DP_z_bank=[0.1715, 0.0849, 0.0495, 0.0656]

diff_prec_a_bank=[0.0125, 0.0129, 0.035,  0.05  ] 
DP_a_bank=[0.0537,  0.054,  0.0376, 0.0335]

diff_prec_y_bank=[-0.0051 , 0.011,   0.0251,  0.0839] 
DP_y_bank=[0.1497, 0.0686 ,0.0276, 0.0069]





diff_lp4_bank_prec=[ 0.0131,  0.0141,  0.0155, -0.0045] 
diff_lp4_bank_rec=[0.0336, 0.1131, 0.1557, 0.1868]
dp_lp4_bank=[ 0.1968, 0.0988, 0.0512, 0.0198]
###########################################################################################33
from matplotlib import pyplot as plt 

#generate a list of markers and another of colors 


mi = markers[0]
ci = colors[1]
plt.scatter(DP_z_bank,diff_prec_z_adult,s=90,marker=mi, color=ci) 


mi = markers[2]
ci = colors[1]
plt.scatter(DP_a_bank,diff_prec_a_bank,s=90,marker=mi, color=ci)


mi = markers[4]
ci = colors[1]
plt.scatter(DP_y_bank,diff_prec_y_bank,s=90,marker=mi, color=ci)



mi = markers[6]
ci = colors[1]
plt.scatter(dp_lp4_bank,diff_lp4_bank_prec,s=90,marker=mi, color=ci)





diff_prec_z_comp=[0.0327 ,0.0069, 0.0209, 0.0369]
diff_rec_z_comp=[-0.0028, -0.0312, -0.036,  -0.0416]
DP_z_comp=[0.1482, 0.0092, 0.07, 0.0668]

diff_rec_a_comp=[0.0161, 0.0003, 0.0044 ,0.0117] 
DP_a_comp=[0.1138 , 0.0742,  0.0541,  0.0251]

diff_prec_y_comp=[0.0057, 0.0686, 0.2221, 0.1143] 
diff_rec_y_comp=[0.0222 ,0.1136 ,0.144 , 0.1579] 
DP_y_comp=[0.2591, 0.0850, 0.0746, 0.0356]

diff_lp4_comp_prec=[0.,      0.0163,  0.02038, 0.0308 ]
diff_lp4_comp_rec=[ 0.,      0.0138, -0.0084, -0.0195]
dp_lp4_comp=[0.3060, 0.1212, 0.0613, 0.0028]

######################################################################################################3
from matplotlib import pyplot as plt 

#generate a list of markers and another of colors 


mi = markers[0]
ci = colors[2]
plt.scatter(DP_z_comp,diff_prec_z_comp,s=90,marker=mi, color=ci) 







mi = markers[4]
ci = colors[2]
plt.scatter(DP_y_comp,diff_prec_y_comp,s=90,marker=mi, color=ci)




mi = markers[6]
ci = colors[2]
plt.scatter(dp_lp4_comp,diff_lp4_comp_prec,s=90,marker=mi, color=ci)
plt.axhline(0, c='black', ls='--')

plt.title('')
ax.set_xlabel('Demographic Parity')
ax.set_ylabel('Weighted Average Precision') 

ax.legend(loc='lower center', bbox_to_anchor=(0.5, -0.30), shadow=True, ncol=10)
plt.show()

# %%
diff_prec_z_adult=[-0.0112,  0.0079,  0.0133 , 0.0565] 
diff_rec_z_adult=[-0.015 ,  0.0014,  0.0485,  0.0564] 
DP_z_adult=[0.1698, 0.1618, 0.157, 0.1074]

diff_prec_a_adult=[ 0.    , -0.0026, -0.0091, -0.0048] 
diff_rec_a_adult=[-0.0109, -0.0013,  0.0235 , 0.0199] 
DP_a_adult=[0.2251,0.2126,0.1266,0.0711]

diff_prec_y_adult=[0.1558 ,0.1084 ,0.1252, 0.1744]
DP_y_adult=[0.1169 ,0.0853, 0.0532,  0.001]

diff_lp4_adult_prec=[0.0076, 0.0208, 0.0505, 0.0608] 
diff_lp4_adult_rec=[0.0411, 0.089 , 0.1687 ,0.1869]
dp_lp4_adult=[ 0.2188, 0.1630,  0.0539, 0.0019]


#########################################################################################3

from matplotlib import pyplot as plt1
fig = plt.figure()
ax = plt.subplot(111)
#generate a list of markers and another of colors 
markers = [3,1,4,5,6,7,'2','1','3','4','P','X']
colors = ['r','g','b','c','m','black']


mi = markers[1]
ci = colors[0]
plt.scatter(DP_z_adult,diff_rec_z_adult,s=90,marker=mi, color=ci,label='')


mi = markers[3]
ci = colors[0]
plt.scatter(DP_z_adult,diff_rec_a_adult,s=90,marker=mi, color=ci,label='')







mi = markers[7]
ci = colors[0]
plt.scatter(dp_lp4_adult,diff_lp4_adult_rec,s=90,marker=mi, color=ci,label='') 

'''
#make a sample dataset
x = np.arange(0,10)  

y = [s*x for s in np.arange(7)] 


for i in range(7): #for each of the 7 features 
    mi = markers[i] #marker for ith feature 
    xi = x #x array for ith feature .. here is where you would generalize      different x for every feature
    yi = y[i] #y array for ith feature 
    ci = colors[i] #color for ith feature 
    plt.scatter(xi,yi,marker=mi, color=ci) 
plt.show() 
'''
diff_prec_z_bank=[0.0622, 0.0515, 0.0262, 0.0523] 
DP_z_bank=[0.1715, 0.0849, 0.0495, 0.0656]

diff_prec_a_bank=[0.0125, 0.0129, 0.035,  0.05  ] 
DP_a_bank=[0.0537,  0.054,  0.0376, 0.0335]

diff_prec_y_bank=[-0.0051 , 0.011,   0.0251,  0.0839] 
DP_y_bank=[0.1497, 0.0686 ,0.0276, 0.0069]





diff_lp4_bank_prec=[ 0.0131,  0.0141,  0.0155, -0.0045] 
diff_lp4_bank_rec=[0.0336, 0.1131, 0.1557, 0.1868]
dp_lp4_bank=[ 0.1968, 0.0988, 0.0512, 0.0198]
###########################################################################################33
from matplotlib import pyplot as plt 

#generate a list of markers and another of colors 







mi = markers[7]
ci = colors[1]
plt.scatter(dp_lp4_bank,diff_lp4_bank_rec,s=90,marker=mi, color=ci)




diff_prec_z_comp=[0.0327 ,0.0069, 0.0209, 0.0369]
diff_rec_z_comp=[-0.0028, -0.0312, -0.036,  -0.0416]
DP_z_comp=[0.1482, 0.0092, 0.07, 0.0668]

diff_rec_a_comp=[0.0161, 0.0003, 0.0044 ,0.0117] 
DP_a_comp=[0.1138 , 0.0742,  0.0541,  0.0251]

diff_prec_y_comp=[0.0057, 0.0686, 0.2221, 0.1143] 
diff_rec_y_comp=[0.0222 ,0.1136 ,0.144 , 0.1579] 
DP_y_comp=[0.2591, 0.0850, 0.0746, 0.0356]

diff_lp4_comp_prec=[0.,      0.0163,  0.02038, 0.0308 ]
diff_lp4_comp_rec=[ 0.,      0.0138, -0.0084, -0.0195]
dp_lp4_comp=[0.3060, 0.1212, 0.0613, 0.0028]

######################################################################################################3
from matplotlib import pyplot as plt 

#generate a list of markers and another of colors 


mi = markers[1]
ci = colors[5]
plt.scatter(DP_z_comp,diff_rec_z_comp,s=90,marker=mi, color=ci,label='(7)') 


mi = markers[3]
ci = colors[5]
plt.scatter(DP_a_comp,diff_rec_a_comp,s=90,marker=mi, color=ci,label='(8)')




mi = markers[5]
ci = colors[5]
plt.scatter(DP_y_comp,diff_rec_y_comp,s=90,marker=mi, color=ci,label='(9)')




mi = markers[7]
ci = colors[5]
plt.scatter(dp_lp4_comp,diff_lp4_comp_rec,s=90,marker=mi, color=ci,label='(10)')

mi = markers[9]
ci = colors[5]
plt.scatter(dp_lp4_comp,diff_lp4_comp_rec,s=90,marker=mi, color=ci,label='(11)')

mi = markers[11]
ci = colors[5]
plt.scatter(dp_lp4_comp,diff_lp4_comp_rec,s=90,marker=mi, color=ci,label='(12)')


plt.axhline(0, c='black', ls='--')
plt.title('')
ax.set_xlabel('Demographic Parity')
ax.set_ylabel('Weighted Average Recall') 

ax.legend(loc='lower center', bbox_to_anchor=(0.5, -0.30), shadow=True, ncol=10)
plt.show()
